# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
a=pd.read_csv("res.csv")
a=a['abs_accuracy']
fig, w = plt.subplots()
fig.set_figwidth(25)
fig.set_figheight(15)
w.plot(a)
w.xaxis.set_major_locator(ticker.MultipleLocator(50))
w.xaxis.set_minor_locator(ticker.MultipleLocator(25))
w.yaxis.set_major_locator(ticker.MultipleLocator(0.0001))
w.yaxis.set_minor_locator(ticker.MultipleLocator(0.00005))
w.grid()
plt.show()
